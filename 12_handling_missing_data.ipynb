# %% [markdown]
# ## <strong> 12. 결측 데이터 처리

# %%
# 필요한 라이브러리
import pandas as pd
import numpy as np

# %% [markdown]
# #### <strong> 결측치의 표현: None 객체

# %%
# None 객체를 포함한 배열
arr1 = np.array([1, 2, None, 4])
print(arr1.dtype)

# 결측치가 없는 배열
arr2 = np.array([1, 2, 3, 4])
print(arr2.dtype)
# Out:
# object
# int64

# %%
# Object 객체는 numpy, pandas 연산과 호환되지 않음
arr1.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 2
#       1 # Object 객체는 numpy, pandas 연산과 호환되지 않음
# ----> 2 arr1.sum()
#
# File C:\Dev\causal(2026)\.venv\Lib\site-packages\numpy\_core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# #### <strong> 결측치의 표현: NaN 값

# %%
# NaN 값을 포함한 배열 객체
arr3 = np.array([1, np.nan, 3, 4])
arr3.dtype
# Out:
# dtype('float64')

# %%
type(np.nan)
# Out:
# float

# %%
# NaN 값에 대한 산술 연산
print(1 + np.nan)
print(0 * np.nan)
print(arr3.sum())
# Out:
# nan
# nan
# nan

# %%
# NaN값을 무시하는 집계함수(numpy)
print(np.nansum(arr3))
print(np.nanmax(arr3))
print(np.nanmin(arr3))
# Out:
# 8.0
# 4.0
# 1.0

# %%
# Pandas는 None 객체를 자동으로 NaN값으로 변환한다.

ser = pd.Series([1, np.nan, 2, None])
print(ser)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %% [markdown]
# ### <strong> Pandas를 이용한 결측치 처리
# ---

# %% [markdown]
# #### <strong>마스킹을 통한 Null 값 표현
# + ```isnull()```
# + ```notnull()```

# %%
# [+] 결측치를 포함한 Series 객체 생성
ser = pd.Series ([1, np.nan,'hello',None])
ser.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
# [+] isnull()
ser.isnull().sum()
# Out:
# np.int64(2)

# %%
# [+] notnull()
ser.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# #### <strong> 결측치를 포함한 행 또는 열 삭제
# + dropna()

# %%
# DataFrame 생성 함수
def make_df(cols, ind):
    data = {c: [str(c) + str(i) for i in ind]
           for c in cols}

    return pd.DataFrame(data, ind)

df = make_df('ABC', [0, 1, 2])
df
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
# [+] NaN 값 추가
df.iloc[0,1] = np.nan
df.iloc[2,1] = np.nan
df
# Out:
#     A    B   C
# 0  A0  NaN  C0
# 1  A1   B1  C1
# 2  A2  NaN  C2

# %%
# [+] 결측치를 포함한 행 삭제
df.dropna(axis = 0)
# Out:
#     A   B   C
# 1  A1  B1  C1

# %%
# [+] 결측치를 포함한 열 삭제
df.dropna(axis = 1)
# Out:
#     A   C
# 0  A0  C0
# 1  A1  C1
# 2  A2  C2

# %%
# [+] NaN 값 추가
df.loc[1, 'B'] = np.nan
df
# Out:
#                      CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  \
# Datetime
# 2004-03-10 18:00:00     2.6       1360.0         1046.0    166.0
# 2004-03-10 19:00:00     2.0       1292.0          955.0    103.0
# 2004-03-10 20:00:00     2.2       1402.0          939.0    131.0
# 2004-03-10 21:00:00     2.2       1376.0          948.0    172.0
# 2004-03-10 22:00:00     1.6       1272.0          836.0    131.0
# ...                     ...          ...            ...      ...
# 2005-04-04 11:00:00     2.4       1163.0         1027.0    353.0
# 2005-04-04 12:00:00     2.4       1142.0         1063.0    293.0
# 2005-04-04 13:00:00     2.1       1003.0          961.0    235.0
# 2005-04-04 14:00:00     2.2       1071.0         1047.0    265.0
# 1                       NaN          NaN            NaN      NaN
#
#                      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH  \
# Datetime
# 2004-03-10 18:00:00        1056.0    113.0        1692.0       1268.0  48.9
# 2004-03-10 19:00:00        1174.0     92.0        1559.0        972.0  47.7
# 2004-03-10 20:00:00        1140.0    114.0        1555.0       1074.0  54.0
# 2004-03-10 21:00:00        1092.0    122.0        1584.0       1203.0  60.0
# 2004-03-10 22:00:00        1205.0    116.0        1490.0       1110.0  59.6
# ...                           ...      ...           ...          ...   ...
# 2005-04-04 11:00:00         604.0    179.0        1264.0       1269.0  23.7
# 2005-04-04 12:00:00         603.0    175.0        1241.0       1092.0  18.3
# 2005-04-04 13:00:00         702.0    156.0        1041.0        770.0  13.5
# 2005-04-04 14:00:00         654.0    168.0        1129.0        816.0  13.1
# 1                             NaN      NaN           NaN          NaN   NaN
#
#                          AH  C6H6(GT)   C   B
# Datetime
# 2004-03-10 18:00:00  0.7578      11.9 NaN NaN
# 2004-03-10 19:00:00  0.7255       9.4 NaN NaN
# 2004-03-10 20:00:00  0.7502       9.0 NaN NaN
# 2004-03-10 21:00:00  0.7867       9.2 NaN NaN
# 2004-03-10 22:00:00  0.7888       6.5 NaN NaN
# ...                     ...       ...  ..  ..
# 2005-04-04 11:00:00  0.7119      11.4 NaN NaN
# 2005-04-04 12:00:00  0.6406      12.4 NaN NaN
# 2005-04-04 13:00:00  0.5139       9.5 NaN NaN
# 2005-04-04 14:00:00  0.5028      11.9 NaN NaN
# 1                       NaN       NaN NaN NaN
#
# [9358 rows x 13 columns]

# %%
# [+] NaN값이 한 개라도 포함되면 행 또는 열 삭제
df.dropna(axis = 0, how = 'any')
# Out:
# Empty DataFrame
# Columns: [CO(GT), PT08.S1(CO), PT08.S2(NMHC), NOx(GT), PT08.S3(NOx), NO2(GT), PT08.S4(NO2), PT08.S5(O3), RH, AH, C6H6(GT), C, B]
# Index: []

# %%
# [+] 모든 값이 전부 NaN값인 행 또는 열 삭제
df.dropna(axis = 1, how = 'all')
# Out:
#                      CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  \
# Datetime
# 2004-03-10 18:00:00     2.6       1360.0         1046.0    166.0
# 2004-03-10 19:00:00     2.0       1292.0          955.0    103.0
# 2004-03-10 20:00:00     2.2       1402.0          939.0    131.0
# 2004-03-10 21:00:00     2.2       1376.0          948.0    172.0
# 2004-03-10 22:00:00     1.6       1272.0          836.0    131.0
# ...                     ...          ...            ...      ...
# 2005-04-04 11:00:00     2.4       1163.0         1027.0    353.0
# 2005-04-04 12:00:00     2.4       1142.0         1063.0    293.0
# 2005-04-04 13:00:00     2.1       1003.0          961.0    235.0
# 2005-04-04 14:00:00     2.2       1071.0         1047.0    265.0
# 1                       NaN          NaN            NaN      NaN
#
#                      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH  \
# Datetime
# 2004-03-10 18:00:00        1056.0    113.0        1692.0       1268.0  48.9
# 2004-03-10 19:00:00        1174.0     92.0        1559.0        972.0  47.7
# 2004-03-10 20:00:00        1140.0    114.0        1555.0       1074.0  54.0
# 2004-03-10 21:00:00        1092.0    122.0        1584.0       1203.0  60.0
# 2004-03-10 22:00:00        1205.0    116.0        1490.0       1110.0  59.6
# ...                           ...      ...           ...          ...   ...
# 2005-04-04 11:00:00         604.0    179.0        1264.0       1269.0  23.7
# 2005-04-04 12:00:00         603.0    175.0        1241.0       1092.0  18.3
# 2005-04-04 13:00:00         702.0    156.0        1041.0        770.0  13.5
# 2005-04-04 14:00:00         654.0    168.0        1129.0        816.0  13.1
# 1                             NaN      NaN           NaN          NaN   NaN
#
#                          AH  C6H6(GT)
# Datetime
# 2004-03-10 18:00:00  0.7578      11.9
# 2004-03-10 19:00:00  0.7255       9.4
# 2004-03-10 20:00:00  0.7502       9.0
# 2004-03-10 21:00:00  0.7867       9.2
# 2004-03-10 22:00:00  0.7888       6.5
# ...                     ...       ...
# 2005-04-04 11:00:00  0.7119      11.4
# 2005-04-04 12:00:00  0.6406      12.4
# 2005-04-04 13:00:00  0.5139       9.5
# 2005-04-04 14:00:00  0.5028      11.9
# 1                       NaN       NaN
#
# [9358 rows x 11 columns]

# %%
# [+] Non-null(정상으로 측정된) 값의 개수가 임계치보다 작은 행을 삭제
df.dropna(axis = 1, thresh = 2)
# Out:
#     A   C
# 0  A0  C0
# 1  A1  C1
# 2  A2  C2

# %%
# [+] Non-null 값의 개수가 임계치보다 작은 열을 삭제
df.dropna(axis = 1, thresh = 2)
# Out:
#     A   C
# 0  A0  C0
# 1  A1  C1
# 2  A2  C2

# %% [markdown]
# #### <strong> NaN값을 다른 값을 대체
# + ```fillna()```

# %%
# Series 객체 생성
ser = pd.Series([1, np.nan, 2, None, 3],
                index=list('abcde'))
ser
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
# [+] 결측치를 특정 값을 대체
ser.fillna(0)
# Out:
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64

# %%
# [+] Forward-fill 방식(= LOCF)
# ser.ffill().fillna(method = 'bfill')
# ser.fillna(method = 'ffill').fillna(method = 'bfill')
ser.ffill().bfill()
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %%
# [+] Backward-fill 방식(= NOCB)
# ser.bfill().fillna(method = 'ffill')
# ser.fillna(method = 'bfill').fillna(method = 'ffill')
ser.bfill().ffill()
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %% [markdown]
# ### <strong> 결측치 처리 예제: Air Quality 데이터셋

# %%
import pandas as pd
from datetime import datetime
from matplotlib import pyplot as plt

def parser(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

# 1. 경로 앞 r 추가 (역슬래시 인식 문제 해결)
input_file = r'C:\data\AirQualityUCI_refined.csv'

# 2. date_parser -> date_format으로 변경 (Pandas 버전 업데이트 반영)
df = pd.read_csv(input_file,
                 index_col=[0],
                 parse_dates=[0],
                 date_format='%Y-%m-%d %H:%M:%S')

# %%
# 데이터 요약
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 9357 entries, 2004-03-10 18:00:00 to 2005-04-04 14:00:00
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CO(GT)         7765 non-null   float64
#  1   PT08.S1(CO)    8991 non-null   float64
#  2   PT08.S2(NMHC)  8991 non-null   float64
#  3   NOx(GT)        7718 non-null   float64
#  4   PT08.S3(NOx)   8991 non-null   float64
#  5   NO2(GT)        7715 non-null   float64
#  6   PT08.S4(NO2)   8991 non-null   float64
#  7   PT08.S5(O3)    8991 non-null   float64
#  8   RH             8991 non-null   float64
#  9   AH             8991 non-null   float64
#  10  C6H6(GT)       9357 non-null   float64
# dtypes: float64(11)
# memory usage: 877.2 KB

# %%
# 시각화 설정 옵션
# %matplotlib qt5
# %config InlineBackend.figure_format = 'svg'

plt.rcParams['figure.figsize'] = [12, 5]
plt.rcParams['font.size'] = 13
plt.ion()

# %%
pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in C:\Dev\causal(2026)\.venv\Lib\site-packages (from missingno) (2.4.4)
# Requirement already satisfied: matplotlib in C:\Dev\causal(2026)\.venv\Lib\site-packages (from missingno) (3.10.8)
# Requirement already satisfied: scipy in C:\Dev\causal(2026)\.venv\Lib\site-packages (from missingno) (1.17.1)
# Requirement already satisfied: seaborn in C:\Dev\causal(2026)\.venv\Lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from matplotlib->missingno) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from matplotlib->missingno) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from matplotlib->missingno) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from matplotlib->missingno) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from matplotlib->missingno) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from matplotlib->missingno) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in C:\Dev\causal(2026)\.venv\Lib\site-packages (from seaborn->missingno) (3.0.2)
# Requirement already satisfied: tzdata in C:\Dev\causal(2026)\.venv\Lib\site-packages (from pandas>=1.2->seaborn->missingno) (2026.1)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: C:\Dev\causal(2026)\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
pip install PyQt5
# Out:
# Collecting PyQt5
#   Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl.metadata (2.1 kB)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5)
#   Downloading pyqt5_sip-12.18.0-cp312-cp312-win_amd64.whl.metadata (516 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from PyQt5)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.9 MB 8.2 MB/s eta 0:00:01
#    ------------------------- -------------- 4.5/6.9 MB 17.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 17.6 MB/s  0:00:00
# Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#    ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#    -- ------------------------------------- 3.4/50.1 MB 20.0 MB/s eta 0:00:03
#    ------ --------------------------------- 7.6/50.1 MB 20.4 MB/s eta 0:00:03
#    --------- ------------------------------ 12.1/50.1 MB 21.0 MB/s eta 0:00:02
#    ------------- -------------------------- 16.8/50.1 MB 21.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 20.2/50.1 MB 20.2 MB/s eta 0:00:02
#    ------------------- -------------------- 24.4/50.1 MB 20.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 29.1/50.1 MB 20.5 MB/s eta 0:00:02
#    --------------------------- ------------ 34.1/50.1 MB 20.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 43.3/50.1 MB 23.5 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 25.3 MB/s eta 0:00:01
#    ---------------------------------------- 50.1/50.1 MB 23.8 MB/s  0:00:02
# Downloading pyqt5_sip-12.18.0-cp312-cp312-win_amd64.whl (58 kB)
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, PyQt5
#
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    -------------------------- ------------- 2/3 [PyQt5]
#    -------------------------- ------------- 2/3 [PyQt5]
#    -------------------------- ------------- 2/3 [PyQt5]
#    -------------------------- ------------- 2/3 [PyQt5]
#    -------------------------- ------------- 2/3 [PyQt5]
#    -------------------------- ------------- 2/3 [PyQt5]
#    -------------------------- ------------- 2/3 [PyQt5]
#    ---------------------------------------- 3/3 [PyQt5]
#
# Successfully installed PyQt5-5.15.11 PyQt5-Qt5-5.15.2 PyQt5-sip-12.18.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: C:\Dev\causal(2026)\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
pip install PySide2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement PySide2 (from versions: none)
#
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: C:\Dev\causal(2026)\.venv\Scripts\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for PySide2

# %%
# 일산화탄소(CO) 시계열 시각화
df['CO(GT)'].plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
# 결측치 대치
imp_locf = df['CO(GT)'].copy().ffill() # LOCF
imp_nocb = df['CO(GT)'].copy().bfill() # NOCB
imp_linear = df['CO(GT)'].copy().interpolate() # 선형 보간
imp_mean = df['CO(GT)'].copy().fillna(df['CO(GT)'].mean())  # 평균값 대체

# %%
# 결측 데이터 시각화
import missingno

missingno.matrix(df)
# Out:
# <Axes: >

# %%
# K-NN 대치
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=2)    # default: 2
imp_knn = df.copy().values
imp_knn = imputer.fit_transform(imp_knn)

# %%
# K-NN 대치 결과 변환(ndarray -> DataFrame)
imp_df = pd.DataFrame(imp_knn, index=imp_locf.index, columns=df.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[129], line 2
#       1 # K-NN 대치 결과 변환(ndarray -> DataFrame)
# ----> 2 imp_df = pd.DataFrame(imp_knn, index=imp_locf.index, columns=df.columns)
#
# File C:\Dev\causal(2026)\.venv\Lib\site-packages\pandas\core\frame.py:814, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     804         mgr = dict_to_mgr(
#     805             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     806             # attribute "name"
#    (...)    811             copy=copy,
#     812         )
#     813     else:
# --> 814         mgr = ndarray_to_mgr(
#     815             data,
#     816             index,
#     817             columns,
#     818             dtype=dtype,
#     819             copy=copy,
#     820         )
#     822 # For data is list-like, or Iterable (will consume into list)
#     823 elif is_list_like(data):
#
# File C:\Dev\causal(2026)\.venv\Lib\site-packages\pandas\core\internals\construction.py:299, in ndarray_to_mgr(values, index, columns, dtype, copy)
#     294 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     295 index, columns = _get_axes(
#     296     values.shape[0], values.shape[1], index=index, columns=columns
#     297 )
# --> 299 _check_values_indices_shape_match(values, index, columns)
#     301 values = values.T
#     303 # if we don't have a dtype specified, then try to convert objects
#     304 # on the entire block; this is to convert if we have datetimelike's
#     305 # embedded in an object type
#
# File C:\Dev\causal(2026)\.venv\Lib\site-packages\pandas\core\internals\construction.py:372, in _check_values_indices_shape_match(values, index, columns)
#     370 passed = values.shape
#     371 implied = (len(index), len(columns))
# --> 372 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (9358, 11), indices imply (9357, 13)

# %%
# 결측치 처리 결과 시각화
plt.plot(df['CO(GT)'], label='actual', zorder=10)
plt.plot(imp_linear, label='linear interpolation', zorder=3)
plt.plot(imp_nocb, label='nocb', zorder=2)
plt.plot(imp_locf, label='locf', zorder=1)
plt.plot(imp_mean, label='mean substitution', zorder=4)
plt.plot(imp_df['CO(GT)'], label='k-nearest neighbor', zorder=5)
plt.legend(loc='best')
plt.show()
